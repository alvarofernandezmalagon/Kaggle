# %% [markdown]
# In this notebook I am going to calculate the average price of the sale of the houses based on the following conditions:
#     - If the house has more than 2 rooms, I segment by:
#         - more than 11,500 square feet.
#         - equal or less than 11,500 square feet.
#
#     - If the house has 2 rooms or less, I segment by :
#         - more than 8,500 square feet.
#         - equal or less than 8,500 square feet

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #### First i'm going to load the 'train.csv' and ckeck the dataframe

# %%
#load training set
training_set = pd.read_csv('train.csv')
pd.options.display.max_columns = None
training_set.sample(5)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1143  1144          20       RL          NaN     9000   Pave   NaN      Reg
# 372    373         120       RL         50.0     7175   Pave   NaN      Reg
# 334    335          60       RL         59.0     9042   Pave   NaN      IR1
# 68      69          30       RM         47.0     4608   Pave   NaN      Reg
# 494    495          30       RM         50.0     5784   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 1143         Lvl    AllPub    Inside       Gtl       Sawyer       Norm
# 372          Lvl    AllPub    Inside       Gtl      SawyerW       Norm
# 334          Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 68           Lvl    AllPub    Corner       Gtl      OldTown     Artery
# 494          Lvl    AllPub    Inside       Gtl      OldTown     Artery
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %% [markdown]
# #### I create field to report if there are equal or less than 2 rooms or if there are more than 2 rooms

# %%
training_set['bedrooms_group'] = training_set['BedroomAbvGr'].apply(lambda x: '+2' if x > 2 else '2 or less')
training_set.sample(5)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1003  1004          90       RL          NaN    11500   Pave   NaN      IR1
# 81      82         120       RM         32.0     4500   Pave   NaN      Reg
# 1044  1045          20       RL         80.0     9600   Pave   NaN      Reg
# 918    919          60       RL        103.0    13125   Pave   NaN      IR1
# 1441  1442         120       RM          NaN     4426   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 1003         Lvl    AllPub    Corner       Gtl       NWAmes      Feedr
# 81           Lvl    AllPub       FR2       Gtl      Mitchel       Norm
# 1044         Lvl    AllPub    Inside       Gtl       NWAmes       PosN
# 918          Lvl    AllPub    Corner       Gtl      SawyerW       Norm
# 1441         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %% [markdown]
# #### I divide the df into two dataframes: one with more than 2 rooms and another with 2 rooms or less.

# %%
more2bedrooms = training_set[training_set['bedrooms_group'] == '+2']
more2bedrooms.sample(5)
# Out:
#       Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 590  591          60       RL         64.0     8320   Pave   NaN      Reg
# 668  669          20       RL          NaN    14175   Pave   NaN      Reg
# 888  889          20       RL         95.0    15865   Pave   NaN      IR1
# 624  625          60       RL         80.0    10400   Pave   NaN      Reg
# 705  706         190       RM         70.0     5600   Pave   NaN      Reg
#
#     LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 590         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 668         Bnk    AllPub    Corner       Mod       Sawyer       Norm
# 888         Lvl    AllPub    Inside       Mod        NAmes       Norm
# 624         Lvl    AllPub    Inside       Gtl       NWAmes       Norm
# 705         Lvl    AllPub    Inside       Gtl       IDOTRR       Norm
#
#     Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
lessEqual2bedrooms = training_set[training_set['bedrooms_group'] == '2 or less'] 
lessEqual2bedrooms.sample(5)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1163  1164          90       RL         60.0    12900   Pave   NaN      Reg
# 1089  1090         120       FV         37.0     3316   Pave  Pave      IR1
# 426    427          80       RL          NaN    12800   Pave   NaN      Reg
# 901    902          20       RL         64.0     8712   Pave   NaN      IR1
# 669    670          30       RL         80.0    11600   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 1163         Lvl    AllPub    Inside       Gtl       Sawyer      Feedr
# 1089         Lvl    AllPub    Inside       Gtl      Somerst       Norm
# 426          Low    AllPub    Inside       Mod      SawyerW       Norm
# 901          Lvl    AllPub    Inside       Gtl        NAmes       Norm
# 669          Lvl    AllPub    Inside       Gtl      Crawfor       Norm
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %% [markdown]
# #### I create another field to report if there are equal or less than 11.500 square feet in the biggest houses or if there are more than 11.500 square feet

# %%
more2bedrooms['square_feet_group'] = more2bedrooms['LotArea'].apply(lambda x: '+11500' if x > 11500 else '11500 or less')
more2bedrooms.sample(5)
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 833    834          20       RL        100.0    10004   Pave   NaN      Reg
# 337    338          20       RL         70.0     9135   Pave   NaN      Reg
# 1314  1315          20       RL         60.0     8190   Pave   NaN      Reg
# 1277  1278          80       RL          NaN    17871   Pave   NaN      IR1
# 487    488          20       RL         70.0    12243   Pave   NaN      IR1
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# ...

# %%
lessEqual2bedrooms['square_feet_group'] = lessEqual2bedrooms['LotArea'].apply(lambda x: '+8500' if x > 8500 else '8500 or less')
lessEqual2bedrooms.sample(5)
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#       Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 821  822          20       RM         60.0     6000   Pave  Pave      Reg
# 710  711          30       RL         56.0     4130   Pave   NaN      IR1
# 428  429          20       RL         64.0     6762   Pave   NaN      Reg
# 736  737          90       RL         60.0     8544   Pave   NaN      Reg
# 771  772          20       RL         67.0     8877   Pave   NaN      Reg
#
#     LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# ...

# %% [markdown]
# #### I'm going to get the average housing price for each of the 4 segmentations made

# %%
prices_more_2_rooms = more2bedrooms.groupby('square_feet_group')[['SalePrice']].mean()
prices_more_2_rooms
# Out:
#                        SalePrice
# square_feet_group
# +11500             233631.638436
# 11500 or less      170227.592693

# %%
prices_equal_less_2_rooms = lessEqual2bedrooms.groupby('square_feet_group')[['SalePrice']].mean()
prices_equal_less_2_rooms
# Out:
#                        SalePrice
# square_feet_group
# +8500              183796.030488
# 8500 or less       145917.172000
